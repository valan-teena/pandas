# %% [markdown]
# #03/08/2024

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Airbnb_updated (1).csv")
df
# Out:
#            _id      property_type        room_type  bed_type  minimum_nights  \
# 0     10066928          Apartment  Entire home/apt  Real Bed               1
# 1     10021707          Apartment     Private room  Real Bed              14
# 2     10009999          Apartment  Entire home/apt  Real Bed               2
# 3     10006546              House  Entire home/apt  Real Bed               2
# 4     10059244          Apartment  Entire home/apt  Real Bed               2
# ...        ...                ...              ...       ...             ...
# 5550   9799412  Bed and breakfast     Private room  Real Bed               1
# 5551   9887054          Apartment     Private room  Real Bed               3
# 5552   9895628          Apartment  Entire home/apt  Real Bed               5
# 5553   9981541          Apartment     Private room  Real Bed               1
# 5554   9983221          Apartment  Entire home/apt  Real Bed               3
#
# ...

# %%
df.sort_values(["beds"],ascending=True).tail(10)
# Out:
#            _id      property_type        room_type  bed_type  minimum_nights  \
# 4056  31095245          Apartment      Shared room  Real Bed               3
# 2178  20958766          Townhouse  Entire home/apt  Real Bed               2
# 1896  19990097              House  Entire home/apt  Real Bed               1
# 5096     73683          Apartment  Entire home/apt  Real Bed               2
# 2157  21929645         Aparthotel     Private room  Real Bed               1
# 358   12509339              House  Entire home/apt  Real Bed               1
# 4437   3410502  Bed and breakfast  Entire home/apt  Real Bed               1
# 4718   4742607          Farm stay  Entire home/apt  Real Bed               3
# 2245   2271702              House  Entire home/apt  Real Bed               5
# 2011  20701559     Boutique hotel     Private room  Real Bed               1
#
#       maximum_nights          cancellation_policy  accommodates  bedrooms  \
# ...

# %%
df.sort_values(["beds"],ascending=True).tail(10).reset_index(drop=True)
# Out:
#         _id      property_type        room_type  bed_type  minimum_nights  \
# 0  31095245          Apartment      Shared room  Real Bed               3
# 1  20958766          Townhouse  Entire home/apt  Real Bed               2
# 2  19990097              House  Entire home/apt  Real Bed               1
# 3     73683          Apartment  Entire home/apt  Real Bed               2
# 4  21929645         Aparthotel     Private room  Real Bed               1
# 5  12509339              House  Entire home/apt  Real Bed               1
# 6   3410502  Bed and breakfast  Entire home/apt  Real Bed               1
# 7   4742607          Farm stay  Entire home/apt  Real Bed               3
# 8   2271702              House  Entire home/apt  Real Bed               5
# 9  20701559     Boutique hotel     Private room  Real Bed               1
#
#    maximum_nights          cancellation_policy  accommodates  bedrooms  beds  \
# ...

# %%
df.sort_values(["beds"],ascending=False).head(10).reset_index(drop=False)
# Out:
#    index       _id      property_type        room_type  bed_type  \
# 0   2011  20701559     Boutique hotel     Private room  Real Bed
# 1   2245   2271702              House  Entire home/apt  Real Bed
# 2   4437   3410502  Bed and breakfast  Entire home/apt  Real Bed
# 3   4718   4742607          Farm stay  Entire home/apt  Real Bed
# 4   2157  21929645         Aparthotel     Private room  Real Bed
# 5    358  12509339              House  Entire home/apt  Real Bed
# 6   5096     73683          Apartment  Entire home/apt  Real Bed
# 7   1896  19990097              House  Entire home/apt  Real Bed
# 8   2178  20958766          Townhouse  Entire home/apt  Real Bed
# 9   2156  21865684             Hostel      Shared room  Real Bed
#
#    minimum_nights  maximum_nights          cancellation_policy  accommodates  \
# 0               1            1125                     flexible            15
# 1               5             180  strict_14_with_grace_period            16
# ...

# %%
df.iloc[600:1200]
# Out:
#            _id property_type        room_type  bed_type  minimum_nights  \
# 600   13183672     Apartment  Entire home/apt  Real Bed              30
# 601     132695     Apartment  Entire home/apt  Real Bed               2
# 602   13272687     Apartment  Entire home/apt  Real Bed               5
# 603   13363311     Apartment  Entire home/apt  Real Bed               2
# 604   13442098     Apartment  Entire home/apt  Real Bed               1
# ...        ...           ...              ...       ...             ...
# 1195  16335870     Apartment  Entire home/apt  Real Bed               2
# 1196  16379687         House     Private room  Real Bed               4
# 1197   1635672     Apartment  Entire home/apt  Real Bed               7
# 1198  16550219     Apartment  Entire home/apt  Real Bed               4
# 1199  16474790     Apartment  Entire home/apt  Real Bed               1
#
#       maximum_nights          cancellation_policy  accommodates  bedrooms  \
# ...

# %%
df.iloc[600:1200:4]
# Out:
#            _id property_type        room_type  bed_type  minimum_nights  \
# 600   13183672     Apartment  Entire home/apt  Real Bed              30
# 604   13442098     Apartment  Entire home/apt  Real Bed               1
# 608   13153996     Apartment  Entire home/apt  Real Bed               4
# 612   13252758     Apartment  Entire home/apt  Real Bed               3
# 616   13609188     Apartment     Private room  Real Bed               1
# ...        ...           ...              ...       ...             ...
# 1180  16258735     Apartment  Entire home/apt  Real Bed               2
# 1184  16341825   Condominium      Shared room  Real Bed               1
# 1188  16316481     Apartment  Entire home/apt  Real Bed               2
# 1192  16336615     Apartment  Entire home/apt  Real Bed               2
# 1196  16379687         House     Private room  Real Bed               4
#
#       maximum_nights          cancellation_policy  accommodates  bedrooms  \
# ...

# %%
df.iloc[600:1200:4,1:6]
# Out:
#      property_type        room_type  bed_type  minimum_nights  maximum_nights
# 600      Apartment  Entire home/apt  Real Bed              30             180
# 604      Apartment  Entire home/apt  Real Bed               1            1125
# 608      Apartment  Entire home/apt  Real Bed               4             365
# 612      Apartment  Entire home/apt  Real Bed               3            1124
# 616      Apartment     Private room  Real Bed               1            1125
# ...            ...              ...       ...             ...             ...
# 1180     Apartment  Entire home/apt  Real Bed               2              14
# 1184   Condominium      Shared room  Real Bed               1            1125
# 1188     Apartment  Entire home/apt  Real Bed               2              40
# 1192     Apartment  Entire home/apt  Real Bed               2              30
# 1196         House     Private room  Real Bed               4            1125
#
# [150 rows x 5 columns]

# %%
df.iloc[[30,90,190,400,600],5:]
# Out:
#      maximum_nights          cancellation_policy  accommodates  bedrooms  \
# 30             1125                     flexible             5         3
# 90               25                     moderate             2         1
# 190            1125                     moderate             4         0
# 400            1125                     moderate             5         2
# 600             180  strict_14_with_grace_period             2         0
#
#      beds  number_of_reviews  bathrooms  price  extra_people  guests_included  \
# 30      3                  0          1    933             0                1
# 90      1                 18          1     72            10                2
# 190     1                 12          1     79            20                2
# 400     4                 44          1     45             9                2
# 600     1                 32          1    140             0                1
#
# ...

# %%
df.iloc[[30,90,190,400,600], 5:20]
# Out:
#      maximum_nights          cancellation_policy  accommodates  bedrooms  \
# 30             1125                     flexible             5         3
# 90               25                     moderate             2         1
# 190            1125                     moderate             4         0
# 400            1125                     moderate             5         2
# 600             180  strict_14_with_grace_period             2         0
#
#      beds  number_of_reviews  bathrooms  price  extra_people  guests_included  \
# 30      3                  0          1    933             0                1
# 90      1                 18          1     72            10                2
# 190     1                 12          1     79            20                2
# 400     4                 44          1     45             9                2
# 600     1                 32          1    140             0                1
#
# ...

# %%
df[df.room_type=="Private room"]
# Out:
#            _id      property_type     room_type       bed_type  \
# 1     10021707          Apartment  Private room       Real Bed
# 9     10133554  Bed and breakfast  Private room       Real Bed
# 10    10138784          Apartment  Private room       Real Bed
# 12    10084023         Guesthouse  Private room          Futon
# 13    10092679          Apartment  Private room  Pull-out Sofa
# ...        ...                ...           ...            ...
# 5547   9944044  Bed and breakfast  Private room       Real Bed
# 5549   9590866          Apartment  Private room       Real Bed
# 5550   9799412  Bed and breakfast  Private room       Real Bed
# 5551   9887054          Apartment  Private room       Real Bed
# 5553   9981541          Apartment  Private room       Real Bed
#
#       minimum_nights  maximum_nights          cancellation_policy  \
# 1                 14            1125                     flexible
# 9                  1            1125                     moderate
# ...

# %%
df.loc[:,["cancellation_policy","accommodates","bedrooms","beds"]]
# Out:
#               cancellation_policy  accommodates  bedrooms  beds
# 0                        flexible             6         3     3
# 1                        flexible             1         1     1
# 2                        flexible             4         1     2
# 3                        moderate             8         3     5
# 4                        moderate             2         0     1
# ...                           ...           ...       ...   ...
# 5550                     flexible             2         1     2
# 5551                     flexible             1         1     1
# 5552                     flexible             8         2     2
# 5553  strict_14_with_grace_period             2         1     2
# 5554  strict_14_with_grace_period             4         1     2
#
# [5555 rows x 4 columns]

# %%
df[df.maximum_nights>=60]
# Out:
#            _id      property_type        room_type  bed_type  minimum_nights  \
# 0     10066928          Apartment  Entire home/apt  Real Bed               1
# 1     10021707          Apartment     Private room  Real Bed              14
# 2     10009999          Apartment  Entire home/apt  Real Bed               2
# 4     10059244          Apartment  Entire home/apt  Real Bed               2
# 5      1001265        Condominium  Entire home/apt  Real Bed               3
# ...        ...                ...              ...       ...             ...
# 5550   9799412  Bed and breakfast     Private room  Real Bed               1
# 5551   9887054          Apartment     Private room  Real Bed               3
# 5552   9895628          Apartment  Entire home/apt  Real Bed               5
# 5553   9981541          Apartment     Private room  Real Bed               1
# 5554   9983221          Apartment  Entire home/apt  Real Bed               3
#
# ...

# %%
df.property_type.value_counts()
# Out:
# property_type
# Apartment                 3626
# House                      606
# Condominium                399
# Serviced apartment         185
# Loft                       142
# Townhouse                  108
# Guest suite                 81
# Bed and breakfast           69
# Boutique hotel              53
# Guesthouse                  50
# Hostel                      34
# Villa                       32
# Hotel                       26
# Aparthotel                  23
# Cottage                     20
# Other                       18
# Cabin                       15
# Bungalow                    14
# Resort                      11
# Farm stay                    9
# Casa particular (Cuba)       9
# Tiny house                   7
# Nature lodge                 2
# Chalet                       2
# Boat                         2
# Camper/RV                    2
# Castle                       1
# Pension (South Korea)        1
# Campsite                     1
# ...

# %%
df[df.maximum_nights.between(600,1125)]
# Out:
#            _id      property_type        room_type  bed_type  minimum_nights  \
# 0     10066928          Apartment  Entire home/apt  Real Bed               1
# 1     10021707          Apartment     Private room  Real Bed              14
# 2     10009999          Apartment  Entire home/apt  Real Bed               2
# 4     10059244          Apartment  Entire home/apt  Real Bed               2
# 8     10120414          Apartment  Entire home/apt  Real Bed               3
# ...        ...                ...              ...       ...             ...
# 5550   9799412  Bed and breakfast     Private room  Real Bed               1
# 5551   9887054          Apartment     Private room  Real Bed               3
# 5552   9895628          Apartment  Entire home/apt  Real Bed               5
# 5553   9981541          Apartment     Private room  Real Bed               1
# 5554   9983221          Apartment  Entire home/apt  Real Bed               3
#
# ...
